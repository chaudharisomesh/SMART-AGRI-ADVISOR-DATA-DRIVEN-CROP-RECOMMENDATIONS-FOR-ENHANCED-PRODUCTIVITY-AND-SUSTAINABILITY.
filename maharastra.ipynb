# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv(r'C:\Users\SOMESH\Desktop\Final Year Project\Crop Yield Data India\archive\maharastra.csv')

# %%
a
# Out:
#                    Crop  Crop_Year       Season        State     Area  \
# 0             Arhar/Tur       2014  Kharif       Maharashtra  1210200
# 1                 Bajra       2014  Kharif       Maharashtra   864800
# 2           Castor seed       2014  Kharif       Maharashtra    17300
# 3          Cotton(lint)       2014  Kharif       Maharashtra  4189900
# 4                  Gram       2014  Rabi         Maharashtra  1427500
# 5             Groundnut       2014  Kharif       Maharashtra   243800
# 6             Groundnut       2014  Summer       Maharashtra    82700
# 7                 Jowar       2014  Kharif       Maharashtra   680100
# 8                 Jowar       2014  Rabi         Maharashtra  2608100
# 9               Linseed       2014  Rabi         Maharashtra    23900
# 10                Maize       2014  Kharif       Maharashtra   800500
# 11                Maize       2014  Rabi         Maharashtra   239800
# ...

# %%
a.head()
# Out:
#            Crop  Crop_Year       Season        State     Area  Production  \
# 0     Arhar/Tur       2014  Kharif       Maharashtra  1210200      353300
# 1         Bajra       2014  Kharif       Maharashtra   864800      537900
# 2   Castor seed       2014  Kharif       Maharashtra    17300        4000
# 3  Cotton(lint)       2014  Kharif       Maharashtra  4189900     3577100
# 4          Gram       2014  Rabi         Maharashtra  1427500     1087700
#
#    Annual_Rainfall  Fertilizer  Pesticide     Yield
# 0           1001.6   182691792     399366  0.313529
# 1           1001.6   130550208     285384  0.451053
# 2           1001.6     2611608       5709  0.188571
# 3           1001.6   632507304    1382667  0.966400
# 4           1001.6   215495400     471075  0.731613

# %%
a.shape
# Out:
# (33, 10)

# %%
a.tail()
# Out:
#          Crop  Crop_Year       Season        State     Area  Production  \
# 28  Sunflower       2014  Rabi         Maharashtra    47900       20700
# 29  Sunflower       2014  Summer       Maharashtra     1900        2000
# 30    Tobacco       2014  Whole Year   Maharashtra     1300        2100
# 31       Urad       2014  Kharif       Maharashtra   276500       92300
# 32      Wheat       2014  Rabi         Maharashtra  1067300     1307700
#
#     Annual_Rainfall  Fertilizer  Pesticide     Yield
# 28           1001.6     7230984      15807  0.326154
# 29           1001.6      286824        627  0.837500
# 30           1001.6      196248        429  1.620000
# 31           1001.6    41740440      91245  0.408788
# 32           1001.6   161119608     352209  1.201379

# %%
a.isnull().sum().sum()
# Out:
# 0

# %%
a.notnull().sum().sum()
# Out:
# 330
