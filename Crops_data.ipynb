# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv(r'C:\Users\SOMESH\Desktop\Final Year Project\Crop-Datasets-for-All-Indian-States-main\Crop-Datasets-for-All-Indian-States-main\Crops_data.csv')

# %%
a
# Out:
#       Dist Code  Year  State Code    State Name  Dist Name  \
# 0             1  2010          14  Chhattisgarh       Durg
# 1             1  2011          14  Chhattisgarh       Durg
# 2             1  2012          14  Chhattisgarh       Durg
# 3             1  2013          14  Chhattisgarh       Durg
# 4             1  2014          14  Chhattisgarh       Durg
# ...         ...   ...         ...           ...        ...
# 2479        917  2013          15     Jharkhand  Singhbhum
# 2480        917  2014          15     Jharkhand  Singhbhum
# 2481        917  2015          15     Jharkhand  Singhbhum
# 2482        917  2016          15     Jharkhand  Singhbhum
# 2483        917  2017          15     Jharkhand  Singhbhum
#
#       RICE AREA (1000 ha)  RICE PRODUCTION (1000 tons)  \
# 0                  777.92                      1319.18
# 1                  806.55                      1416.48
# 2                  807.07                      1534.22
# ...

# %%
a.shape
# Out:
# (2484, 80)

# %%
a.head()
# Out:
#    Dist Code  Year  State Code    State Name Dist Name  RICE AREA (1000 ha)  \
# 0          1  2010          14  Chhattisgarh      Durg               777.92
# 1          1  2011          14  Chhattisgarh      Durg               806.55
# 2          1  2012          14  Chhattisgarh      Durg               807.07
# 3          1  2013          14  Chhattisgarh      Durg               819.44
# 4          1  2014          14  Chhattisgarh      Durg               834.87
#
#    RICE PRODUCTION (1000 tons)  RICE YIELD (Kg per ha)  WHEAT AREA (1000 ha)  \
# 0                      1319.18                 1695.77                 46.12
# 1                      1416.48                 1756.23                 44.98
# 2                      1534.22                 1900.97                 43.87
# 3                      1296.24                 1581.86                 41.54
# 4                      1444.24                 1729.89                 44.25
#
# ...

# %%
a.tail()
# Out:
#       Dist Code  Year  State Code State Name  Dist Name  RICE AREA (1000 ha)  \
# 2479        917  2013          15  Jharkhand  Singhbhum               267.06
# 2480        917  2014          15  Jharkhand  Singhbhum               256.33
# 2481        917  2015          15  Jharkhand  Singhbhum               263.21
# 2482        917  2016          15  Jharkhand  Singhbhum               224.05
# 2483        917  2017          15  Jharkhand  Singhbhum               386.91
#
#       RICE PRODUCTION (1000 tons)  RICE YIELD (Kg per ha)  \
# 2479                       579.70                 2170.67
# 2480                       586.63                 2288.57
# 2481                       264.71                 1005.70
# 2482                       319.01                 1423.84
# 2483                       669.97                 1731.62
#
#       WHEAT AREA (1000 ha)  WHEAT PRODUCTION (1000 tons)  ...  \
# 2479                  1.53                          1.85  ...
# ...

# %%
a.isnull().sum().sum()
# Out:
# 0

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 80 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Dist Code                                    2484 non-null   int64
#  1   Year                                         2484 non-null   int64
#  2   State Code                                   2484 non-null   int64
#  3   State Name                                   2484 non-null   object
#  4   Dist Name                                    2484 non-null   object
#  5   RICE AREA (1000 ha)                          2484 non-null   float64
#  6   RICE PRODUCTION (1000 tons)                  2484 non-null   float64
#  7   RICE YIELD (Kg per ha)                       2484 non-null   float64
#  8   WHEAT AREA (1000 ha)                         2484 non-null   float64
# ...
